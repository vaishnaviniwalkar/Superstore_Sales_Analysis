# %% [markdown]
# # Superstore Sales Analysis
#
# ## Objective
#
# The objective of this project is to analyze the Superstore dataset and derive meaningful business insights using Python libraries like Pandas, Matplotlib, and Seaborn.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/Sample - Superstore.csv", encoding="latin1")

# %%
df.head(3)
# Out:
#    Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 1       2  CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
# 2       3  CA-2016-138688  6/12/2016   6/16/2016  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# Creating new columns for easy analysis

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month_name()

# %%
df['Shipping days'] = (df['Ship Date'] - df['Order Date']).dt.days

# %%
df[['Year', 'Month', 'Shipping days']].head()
# Out:
#    Year     Month  Shipping days
# 0  2016  November              3
# 1  2016  November              3
# 2  2016      June              4
# 3  2015   October              7
# 4  2015   October              7

# %% [markdown]
# Checking negative profit

# %%
df[df['Profit']<0]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 14        15  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 15        16  US-2015-118983 2015-11-22 2015-11-26  Standard Class
# 23        24  US-2017-156909 2017-07-16 2017-07-18    Second Class
# 27        28  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# ...      ...             ...        ...        ...             ...
# 9920    9921  CA-2016-149272 2016-03-15 2016-03-19  Standard Class
# 9921    9922  CA-2014-111360 2014-11-24 2014-11-30  Standard Class
# 9931    9932  CA-2015-104948 2015-11-13 2015-11-17  Standard Class
# 9937    9938  CA-2016-164889 2016-06-03 2016-06-06    Second Class
# 9962    9963  CA-2015-168088 2015-03-19 2015-03-22     First Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 3       SO-20335    Sean O'Donnell     Consumer  United States
# ...

# %% [markdown]
# ## Business Analysis

# %%
print("total Profit: ", df['Profit'].sum())
print("total Sales: ", df['Sales'].sum())
# Out:
# total Profit:  286397.0217
# total Sales:  2297200.8603

# %% [markdown]
# The company generated total sales of ₹2297200.8603 and a total profit of ₹286397.0217.

# %%
df['Sales'].mean()
# Out:
# np.float64(229.85800083049827)

# %% [markdown]
# Average sale per order = 229.86

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
category_sales
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
sns.barplot(x='Category', y='Sales', data=category_sales.reset_index(),hue='Category', palette="Accent")
plt.title('Sales by Category')
plt.show()

# %% [markdown]
# From the graph , Top selling category is technology
# lowest selling category is office supplies

# %%
category_profit = df.groupby("Category")["Profit"].sum().sort_values(ascending=False)
category_profit
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
sns.barplot(x='Category', y='Profit', data=category_profit.reset_index(), hue='Category', palette='Accent')
plt.title('Profit by Category')
plt.show()

# %% [markdown]
# Top profit category is technology,
# Furniture have low profit
# This means category with highest sales have highest profit

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
region_sales
# Out:
# Region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: Sales, dtype: float64

# %%
sns.barplot(x='Region', y='Sales', data=region_sales.reset_index(), hue='Region', palette='Accent')
plt.title('Sales by Region')
plt.show()

# %% [markdown]
# West region generated highest sales, south region generated lowest sales

# %%
region_profit = df.groupby('Region')['Profit'].sum().sort_values(ascending=False)
region_profit
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %%
sns.barplot(x='Region', y='Profit', data=region_profit.reset_index(), hue='Region', palette='Accent')
plt.title('Profit by Region')
plt.show()

# %% [markdown]
# West region generated maximum profit and cemtral region has lowest profit.
# Region with highest sales has highest profit

# %%
top_sales_states = df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10)
top_sales_states
# Out:
# State
# California      457687.6315
# New York        310876.2710
# Texas           170188.0458
# Washington      138641.2700
# Pennsylvania    116511.9140
# Florida          89473.7080
# Illinois         80166.1010
# Ohio             78258.1360
# Michigan         76269.6140
# Virginia         70636.7200
# Name: Sales, dtype: float64

# %%
sns.barplot(x='State', y='Sales', data=top_sales_states.reset_index(), hue='State', palette='Accent')
plt.title('Top 10 States by Sales')
plt.xticks(rotation=35)
plt.show()

# %% [markdown]
# California generated maximum sales

# %%
top_profit_state = df.groupby('State')['Profit'].sum().sort_values(ascending=False).head(10)
top_profit_state
# Out:
# State
# California    76381.3871
# New York      74038.5486
# Washington    33402.6517
# Michigan      24463.1876
# Virginia      18597.9504
# Indiana       18382.9363
# Georgia       16250.0433
# Kentucky      11199.6966
# Minnesota     10823.1874
# Delaware       9977.3748
# Name: Profit, dtype: float64

# %%
sns.barplot(x='State', y='Profit', data=top_profit_state.reset_index(), hue='State', palette='Accent')
plt.xticks(rotation=35)
plt.title('Top 10 States by Profit')
plt.show()

# %% [markdown]
# California generated maximum profit
# California is best performing state in profit as well as sales

# %%
bottom_profit_state = df.groupby('State')['Profit'].sum().sort_values().head(10)
bottom_profit_state
# Out:
# State
# Texas            -25729.3563
# Ohio             -16971.3766
# Pennsylvania     -15559.9603
# Illinois         -12607.8870
# North Carolina    -7490.9122
# Colorado          -6527.8579
# Tennessee         -5341.6936
# Arizona           -3427.9246
# Florida           -3399.3017
# Oregon            -1190.4705
# Name: Profit, dtype: float64

# %%
sns.barplot(x='State', y="Profit", data=bottom_profit_state.reset_index(), hue='State', palette='Accent')
plt.xticks(rotation=35)
plt.title('Bottom 10 States by Profit')
plt.show()

# %% [markdown]
# Above 10 States are generating losses.
# Texas generated maximum loss.

# %%
top_customers = df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).head(10)
top_customers
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
sns.barplot(x='Sales', y='Customer Name', data=top_customers.reset_index(),orient='h', hue='Customer Name', palette='Accent')
plt.title('Top 10 Customers by Sales')
plt.show()

# %% [markdown]
# Sean Miller is the top customer

# %%
segment_sales = df.groupby('Segment')['Sales'].sum().sort_values(ascending=False)
segment_sales
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
plt.pie(segment_sales, labels=segment_sales.index, autopct='%1.1f%%', explode=(0.05,0,0))
plt.title('Percentage contribution by Customer Segment')
plt.show()

# %% [markdown]
# Consumer segment contributes the highest share of total sales.

# %%
segment_profit = df.groupby('Segment')['Profit'].sum().sort_values(ascending=False)
segment_profit
# Out:
# Segment
# Consumer       134119.2092
# Corporate       91979.1340
# Home Office     60298.6785
# Name: Profit, dtype: float64

# %%
subcategory_sales = df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)
subcategory_sales
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %%
sns.barplot(x='Sub-Category', y='Sales', data=subcategory_sales.reset_index(), hue='Sub-Category', palette='Accent')
plt.title('Subcategory  by Sales')
plt.xticks(rotation=60)

plt.show()

# %% [markdown]
# Phones has the highest sales, chairs also have almost same sales but ranked 2nd.

# %%
subcategory_profit = df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False)
subcategory_profit
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
sns.barplot(x='Sub-Category', y='Profit', data=subcategory_profit.reset_index(), hue='Sub-Category', palette='Accent')
plt.xticks(rotation=60)
plt.title('Subcategory by Profit')
plt.show()

# %% [markdown]
# Copiers earns the highest profit. Tables causes the maximum loss. Other subcategories like Bookcases and Suppliers also cause loss.

# %%
top_sales_product = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)
top_sales_product
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
sns.barplot(x='Sales', y='Product Name', data=top_sales_product.reset_index(), hue='Product Name', palette='Accent', orient='h')
plt.title('Top 10 Products by Sales')

plt.show()

# %% [markdown]
# Canon imageCLASS 2200 Advanced Copier has the largest sales among all the products

# %%
top_profit_product = df.groupby('Product Name')['Profit'].sum().sort_values(ascending=False).head(10)
top_profit_product
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     7753.0390
# Hewlett Packard LaserJet 3310 Copier                                            6983.8836
# Canon PC1060 Personal Laser Copier                                              4570.9347
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                       4094.9766
# Ativa V4110MDD Micro-Cut Shredder                                               3772.9461
# 3D Systems Cube Printer, 2nd Generation, Magenta                                3717.9714
# Plantronics Savi W720 Multi-Device Wireless Headset System                      3696.2820
# Ibico EPK-21 Electric Binding System                                            3345.2823
# Zebra ZM400 Thermal Label Printer                                               3343.5360
# Name: Profit, dtype: float64

# %%
sns.barplot(x='Profit', y='Product Name', data=top_profit_product.reset_index(), hue='Product Name', palette='Accent', orient='h')
plt.title('Top 10 Products by Profit')
plt.show()

# %% [markdown]
# Canon imageCLASS 2200 Advanced Copier has the largest profit among all yhe products. The product with highet sales has highest profit
